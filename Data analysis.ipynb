# %%
#Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
file_path3 = "Data_Sources/title.basics.tsv.gz"
title_basics_df = pd.read_csv(file_path3, compression='gzip', sep='\t')
title_basics_df.head()
# Out:
# C:\Users\amudd\AppData\Local\Temp\ipykernel_14376\882156001.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_basics_df = pd.read_csv(file_path3, compression='gzip', sep='\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics_df.nunique()
# Out:
# tconst            9590764
# titleType              11
# primaryTitle      4365467
# originalTitle     4386780
# isAdult                11
# startYear             152
# endYear                97
# runtimeMinutes        885
# genres               2343
# dtype: int64

# %%
for i in title_basics_df.columns:
    print(i, len(title_basics_df[i].unique()))
# Out:
# tconst 9590764
# titleType 11
# primaryTitle 4365468
# originalTitle 4386781
# isAdult 11
# startYear 152
# endYear 97
# runtimeMinutes 885
# genres 2344

# %%
title_basics_df.isnull().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
middle_index = len(title_basics_df) // 2

#displaying first few rows and last few rows around the middle
print(title_basics_df.iloc[middle_index-5:middle_index+5])
# Out:
#              tconst  titleType     primaryTitle    originalTitle isAdult  \
# 4795377   tt1828259      short     Oi kanapedes     Oi kanapedes       0
# 4795378  tt18282600  tvEpisode  Episode #1.2627  Episode #1.2627       0
# 4795379  tt18282602  tvEpisode  Episode #1.2628  Episode #1.2628       0
# 4795380  tt18282604  tvEpisode  Episode #1.2629  Episode #1.2629       0
# 4795381  tt18282606  tvEpisode  Episode #1.2630  Episode #1.2630       0
# 4795382   tt1828260      movie     On the Ropes     On the Ropes       0
# 4795383  tt18282610  tvEpisode  Episode #1.2632  Episode #1.2632       0
# 4795384  tt18282612  tvEpisode  Episode #1.2631  Episode #1.2631       0
# 4795385  tt18282614  tvEpisode  Episode #1.2633  Episode #1.2633       0
# 4795386  tt18282616  tvEpisode  Episode #1.2634  Episode #1.2634       0
#
#         startYear endYear runtimeMinutes                      genres
# 4795377      1998      \N              5                       Short
# 4795378        \N      \N             \N  Adventure,Animation,Comedy
# 4795379        \N      \N             \N  Adventure,Animation,Comedy
# 4795380        \N      \N             \N  Adventure,Animation,Comedy
# 4795381        \N      \N             \N  Adventure,Animation,Comedy
# 4795382      2011      \N             94                      Comedy
# 4795383        \N      \N             \N  Adventure,Animation,Comedy
# 4795384        \N      \N             \N  Adventure,Animation,Comedy
# 4795385        \N      \N             \N  Adventure,Animation,Comedy
# 4795386        \N      \N             \N  Adventure,Animation,Comedy

# %%
title_types = title_basics_df['titleType'].value_counts()
print(title_types)
# Out:
# tvEpisode       7264307
# short            912329
# movie            634711
# video            270131
# tvSeries         238109
# tvMovie          140300
# tvMiniSeries      47111
# tvSpecial         40402
# videoGame         33439
# tvShort            9923
# tvPilot               2
# Name: titleType, dtype: int64

# %% [markdown]
# #### For the movie recommendation system we only need the movies and all values associated with movies ####

# %%
movietitle_df = title_basics_df[title_basics_df['titleType'] == 'movie']
movietitle_df
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# ...            ...       ...
# 9590655  tt9916622     movie
# 9590682  tt9916680     movie
# 9590694  tt9916706     movie
# 9590704  tt9916730     movie
# 9590714  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# ...                                                    ...
# 9590655        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9590682  De la ilusión al desconcierto: cine colombiano...
# 9590694                                    Dankyavar Danka
# 9590704                                             6 Gunn
# 9590714                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 498                                               Bohemios       0      1905
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# ...                                                    ...     ...       ...
# 9590655        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9590682  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9590694                                    Dankyavar Danka       0      2013
# 9590704                                             6 Gunn       0      2017
# 9590714                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8            \N             45                     Romance
# 144          \N            100      Documentary,News,Sport
# 498          \N            100                          \N
# 570          \N             70  Action,Adventure,Biography
# 587          \N             90                       Drama
# ...         ...            ...                         ...
# 9590655      \N             57                 Documentary
# 9590682      \N            100                 Documentary
# 9590694      \N             \N                      Comedy
# 9590704      \N            116                          \N
# 9590714      \N             49                 Documentary
#
# [634711 rows x 9 columns]

# %%
#originalTitle (string) - original title, in the original language. We do need this column as primaryTitle is the title when film was released to public.
movietitle_df = movietitle_df.drop(columns=['originalTitle'])

# %%
movietitle_df = movietitle_df.reset_index(drop=True)
movietitle_df.tail(30)
# Out:
#            tconst titleType  \
# 634681  tt9915456     movie
# 634682  tt9915536     movie
# 634683  tt9915592     movie
# 634684  tt9915736     movie
# 634685  tt9915790     movie
# 634686  tt9915808     movie
# 634687  tt9915872     movie
# 634688  tt9915946     movie
# 634689  tt9916058     movie
# 634690  tt9916100     movie
# 634691  tt9916124     movie
# 634692  tt9916132     movie
# 634693  tt9916134     movie
# 634694  tt9916160     movie
# 634695  tt9916162     movie
# 634696  tt9916170     movie
# 634697  tt9916178     movie
# 634698  tt9916186     movie
# 634699  tt9916188     movie
# 634700  tt9916190     movie
# 634701  tt9916270     movie
# 634702  tt9916362     movie
# 634703  tt9916428     movie
# 634704  tt9916538     movie
# 634705  tt9916620     movie
# 634706  tt9916622     movie
# 634707  tt9916680     movie
# 634708  tt9916706     movie
# 634709  tt9916730     movie
# 634710  tt9916754     movie
#
#                                              primaryTitle isAdult startYear  \
# 634681                                     Faith's Choice       0        \N
# 634682                                        Side Effect       0        \N
# 634683                                  A Husband to Rent       0      1974
# 634684                                        Liebestraum       0        \N
# 634685                                    Bobbyr Bondhura       0      2019
# 634686                                          Salt Lake       0        \N
# 634687                               The Last White Witch       0      2019
# 634688                                   Nuestra película       0      1993
# 634689                           Cali: ayer, hoy y mañana       0      1995
# 634690                              Inventing Robert Capa       0        \N
# 634691                                        Mucho gusto       0      1997
# 634692                       The Mystery of a Buryat Lama       0      2018
# 634693                               The Thing in the Bag       0        \N
# 634694                                         Drømmeland       0      2019
# 634695              Making of 'La Virgen de los sicarios'       0      1999
# 634696                                      The Rehearsal       0      2019
# 634697                                 Yesterday's Dreams       0        \N
# 634698  Illenau - die Geschichte einer ehemaligen Heil...       0      2017
# 634699                                           Minotaur       0        \N
# 634700                                          Safeguard       0      2020
# 634701                           Il talento del calabrone       0      2020
# 634702                                              Coven       0      2020
# 634703                                The Secret of China       0      2019
# 634704                                Kuambil Lagi Hatiku       0      2019
# 634705                                  The Copeland Case       0        \N
# 634706        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 634707  De la ilusión al desconcierto: cine colombiano...       0      2007
# 634708                                    Dankyavar Danka       0      2013
# 634709                                             6 Gunn       0      2017
# 634710                     Chico Albuquerque - Revelações       0      2013
#
#        endYear runtimeMinutes                         genres
# 634681      \N             \N                          Drama
# 634682      \N             \N                  Action,Sci-Fi
# 634683      \N             \N                         Comedy
# 634684      \N             \N                        Musical
# 634685      \N            106                         Family
# 634686      \N             \N                 Drama,Thriller
# 634687      \N             97           Comedy,Drama,Fantasy
# 634688      \N             96                    Documentary
# 634689      \N            250                    Documentary
# 634690      \N             \N            Biography,Drama,War
# 634691      \N            108                    Documentary
# 634692      \N             94  Biography,Documentary,History
# 634693      \N             78                             \N
# 634694      \N             72                    Documentary
# 634695      \N             45                    Documentary
# 634696      \N             51                          Drama
# 634697      \N             \N                             \N
# 634698      \N             84                    Documentary
# 634699      \N             \N                       Thriller
# 634700      \N             95      Action,Adventure,Thriller
# 634701      \N             84                       Thriller
# 634702      \N             92                  Drama,History
# 634703      \N             \N          Adventure,History,War
# 634704      \N            123                          Drama
# 634705      \N             \N                          Drama
# 634706      \N             57                    Documentary
# 634707      \N            100                    Documentary
# 634708      \N             \N                         Comedy
# 634709      \N            116                             \N
# 634710      \N             49                    Documentary

# %%
#Checking for popular movies
target_titles = ['Avatar', 'Avengers', 'Star Wars', 'Superbad', 'Thor', 'Avengers: Endgame']
mask = movietitle_df['primaryTitle'].isin(target_titles)
result = movietitle_df.loc[mask]
print(result)
# Out:
#             tconst titleType       primaryTitle isAdult startYear endYear  \
# 97569    tt0154182     movie             Avatar       0      1941      \N
# 154530   tt0278325     movie             Avatar       0      1916      \N
# 214632   tt0499549     movie             Avatar       0      2009      \N
# 217404   tt0800369     movie               Thor       0      2011      \N
# 219303   tt0829482     movie           Superbad       0      2007      \N
# 325693  tt14473344     movie               Thor       0      1985      \N
# 375186   tt1775309     movie             Avatar       0      2011      \N
# 501646   tt4154796     movie  Avengers: Endgame       0      2019      \N
# 529458   tt5151440     movie               Thor       0      1962      \N
#
#        runtimeMinutes                    genres
# 97569              \N                     Drama
# 154530             50             Drama,Fantasy
# 214632            162  Action,Adventure,Fantasy
# 217404            115            Action,Fantasy
# 219303            113                    Comedy
# 325693             \N                     Drama
# 375186             93                    Horror
# 501646            181    Action,Adventure,Drama
# 529458             \N            Action,Fantasy

# %%
freq_ofN = movietitle_df[movietitle_df == '\\N'].count()
print(freq_ofN)
# Out:
# tconst                 0
# titleType              0
# primaryTitle           0
# isAdult                0
# startYear          88112
# endYear           634711
# runtimeMinutes    233954
# genres             71758
# dtype: int64

# %%
movietitle_df.shape
# Out:
# (634711, 8)

# %%
file_path6 = "Data_Sources/title.ratings.tsv.gz"
title_ratings_df = pd.read_csv(file_path6, compression='gzip', sep='\t')
title_ratings_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1949
# 1  tt0000002            5.8       264
# 2  tt0000003            6.5      1779
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2583

# %%
title_ratings_df.shape
# Out:
# (1276330, 3)

# %%
title_ratings_df.nunique()
# Out:
# tconst           1276330
# averageRating         91
# numVotes           21031
# dtype: int64

# %%
title_ratings_df.isnull().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
print (title_ratings_df.shape)
print (movietitle_df.shape)
# Out:
# (1276330, 3)
# (634711, 8)

# %%
#Need to filter ratings df to only display ratings of movies, then merge on tconst.
movie_title_ratings_df = title_ratings_df[title_ratings_df["tconst"].isin(title_basics_df[title_basics_df["titleType"] == "movie"]["tconst"])]
movie_title_ratings_df.head(10)
# Out:
#         tconst  averageRating  numVotes
# 8    tt0000009            5.3       204
# 144  tt0000147            5.2       466
# 325  tt0000502            4.1        15
# 357  tt0000574            6.0       808
# 364  tt0000591            4.4        20
# 378  tt0000615            4.3        24
# 385  tt0000630            2.8        26
# 415  tt0000675            4.2        20
# 417  tt0000679            5.2        67
# 525  tt0000862            4.4        17

# %%
movie_title_ratings_df = movie_title_ratings_df.reset_index(drop=True)
movie_title_ratings_df.head(10)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000009            5.3       204
# 1  tt0000147            5.2       466
# 2  tt0000502            4.1        15
# 3  tt0000574            6.0       808
# 4  tt0000591            4.4        20
# 5  tt0000615            4.3        24
# 6  tt0000630            2.8        26
# 7  tt0000675            4.2        20
# 8  tt0000679            5.2        67
# 9  tt0000862            4.4        17

# %%
print(movietitle_df.shape)
print(movie_title_ratings_df.shape)
# Out:
# (634711, 8)
# (286806, 3)

# %%
#merging the dataframes
merged_df = pd.merge(movietitle_df, movie_title_ratings_df, on='tconst', how='inner')
merged_df.tail(30)
# Out:
#            tconst titleType                  primaryTitle isAdult startYear  \
# 286776  tt9910930     movie                   Jeg ser deg       0      2019
# 286777  tt9911006     movie                         Ormma       0      2019
# 286778  tt9911196     movie           The Marriage Escape       0      2020
# 286779  tt9911306     movie                Kalikkoottukar       0      2019
# 286780  tt9911774     movie     Padmavyuhathile Abhimanyu       0      2019
# 286781  tt9913056     movie                  Swarm Season       0      2019
# 286782  tt9913084     movie              Diabolik sono io       0      2019
# 286783  tt9913660     movie                    No Apology       0      2019
# 286784  tt9913872     movie         De la piel del Diablo       0      2019
# 286785  tt9913936     movie                      Paradise       0      2019
# 286786  tt9914192     movie           No Gogó do Paulinho       0      2020
# 286787  tt9914254     movie                 A Cherry Tale       0      2019
# 286788  tt9914286     movie             Sokagin Çocuklari       0      2019
# 286789  tt9914642     movie                     Albatross       0      2017
# 286790  tt9914644     movie  9/11: Escape from the Towers       0      2018
# 286791  tt9914662     movie   Wien is 't Hof van Commerce       0      2018
# 286792  tt9914942     movie        Life Without Sara Amat       0      2019
# 286793  tt9914972     movie                Blind Ambition       0      2021
# 286794  tt9915436     movie             Vida em Movimento       0      2019
# 286795  tt9915790     movie               Bobbyr Bondhura       0      2019
# 286796  tt9915872     movie          The Last White Witch       0      2019
# 286797  tt9915946     movie              Nuestra película       0      1993
# 286798  tt9916160     movie                    Drømmeland       0      2019
# 286799  tt9916170     movie                 The Rehearsal       0      2019
# 286800  tt9916190     movie                     Safeguard       0      2020
# 286801  tt9916270     movie      Il talento del calabrone       0      2020
# 286802  tt9916362     movie                         Coven       0      2020
# 286803  tt9916428     movie           The Secret of China       0      2019
# 286804  tt9916538     movie           Kuambil Lagi Hatiku       0      2019
# 286805  tt9916730     movie                        6 Gunn       0      2017
#
#        endYear runtimeMinutes                     genres  averageRating  \
# 286776      \N             75          Crime,Documentary            5.6
# 286777      \N            127                      Drama            6.9
# 286778      \N            103               Comedy,Drama            7.5
# 286779      \N            145              Drama,Romance            3.2
# 286780      \N            130                      Drama            8.5
# 286781      \N             86                Documentary            6.6
# 286782      \N             75                Documentary            6.8
# 286783      \N            102                      Drama            5.6
# 286784      \N             75                   Thriller            3.4
# 286785      \N            135                Crime,Drama            7.5
# 286786      \N             98                     Comedy            5.4
# 286787      \N             85                Documentary            7.1
# 286788      \N             98               Drama,Family            5.0
# 286789      \N             97                Documentary            8.3
# 286790      \N            120                Documentary            8.3
# 286791      \N             \N                     Comedy            7.4
# 286792      \N             74                      Drama            6.7
# 286793      \N             96                Documentary            7.2
# 286794      \N             70                Documentary            7.4
# 286795      \N            106                     Family            7.2
# 286796      \N             97       Comedy,Drama,Fantasy            7.3
# 286797      \N             96                Documentary            6.9
# 286798      \N             72                Documentary            6.3
# 286799      \N             51                      Drama            7.0
# 286800      \N             95  Action,Adventure,Thriller            3.7
# 286801      \N             84                   Thriller            5.8
# 286802      \N             92              Drama,History            6.4
# 286803      \N             \N      Adventure,History,War            3.8
# 286804      \N            123                      Drama            8.3
# 286805      \N            116                         \N            8.1
#
#         numVotes
# 286776         9
# 286777         9
# 286778      2841
# 286779        22
# 286780       378
# 286781        36
# 286782        48
# 286783        68
# 286784        16
# 286785        59
# 286786       279
# 286787         8
# 286788       217
# 286789        42
# 286790       107
# 286791         6
# 286792       171
# 286793       238
# 286794         5
# 286795        39
# 286796         8
# 286797         9
# 286798        50
# 286799         7
# 286800       241
# 286801      1392
# 286802      5175
# 286803        14
# 286804         6
# 286805         9
